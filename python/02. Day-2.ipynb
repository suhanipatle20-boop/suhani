# %%
var = "hello"

# %%
a, b, c, d = 10, 20 ,30 ,40

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
d
# Out:
# 40

# %%
a + b
# Out:
# 30

# %%
d - b
# Out:
# 20

# %%
c/a
# Out:
# 3.0

# %%
c%a
# Out:
# 0

# %%
30/10
# Out:
# 3.0

# %%
30/3
# Out:
# 10.0

# %%
30%3
# Out:
# 0

# %%
31//3
# Out:
# 10

# %%
31%3
# Out:
# 1

# %%
3**3
# Out:
# 27

# %%
4**2
# Out:
# 16

# %%
b**a
# Out:
# 10240000000000

# %%
b*a
# Out:
# 200

# %%
b > c
# Out:
# False

# %%
d < a
# Out:
# False

# %%
d > B
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 d > B
#
# NameError: name 'B' is not defined

# %%
c > b and a /b
# Out:
# 0.5

# %%
a < b and c > d
 # T and F
# Out:
# False

# %%
a < b and c < d
# Out:
# True

# %%
a > b or c< d
# Out:
# True

# %%
not(a < b)
# Out:
# False

# %%
a> b and d%a < c-b or b==c and a< c
# Out:
# False

# %%
30+5-(60/3)/2 + 5 *2
# Out:
# 35.0

# %%
15
20
50
35

# %%
BODMAS

# %%
True or True and True and False

# %%
30 != 30
# Out:
# False

# %%
30 == 30
# Out:
# True

# %%
45//16
# Out:
# 2

# %%
46%9
# Out:
# 1

# %% [markdown]
# ### type casting

# %%
var
# Out:
# 'hello'

# %%
type(var)
# Out:
# str

# %%
lis = list(var)

# %%
lis
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
tuple(lis)
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
set(lis)
# Out:
# {'e', 'h', 'l', 'o'}

# %%
dict(lis)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dict(lis)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
var = "98766"

# %%
type(var)
# Out:
# str

# %%
type(int(var))
# Out:
# int

# %%
lang = "py3.1"

# %%
type(lang)
# Out:
# str

# %%
int(lang)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 int(lang)
#
# ValueError: invalid literal for int() with base 10: 'py3.1'

# %%
num1 = True

# %%
type(num1)
# Out:
# bool

# %%
int(num1)
# Out:
# 1

# %%
str(num1)
# Out:
# 'True'

# %%
l1 = [1,2,3,4,5,6,7,8]

# %%
dict(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 dict(l1)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
l1 = [(1,2),(3,4),(5,6),(7,8)]

# %%
type(l1)
# Out:
# list

# %%
t1 = tuple(l1)

# %%
s1 = set(l1)

# %%
dict(l1)
# Out:
# {1: 2, 3: 4, 5: 6, 7: 8}

# %%
t1
# Out:
# ((1, 2), (3, 4), (5, 6), (7, 8))

# %%
dict(t1)
# Out:
# {1: 2, 3: 4, 5: 6, 7: 8}

# %%
s1
# Out:
# {(1, 2), (3, 4), (5, 6), (7, 8)}

# %%
d1 = dict(s1)

# %%
l1 = [(1,2),(3,4),(5,6),(7,8), 7]

# %%
dict(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 dict(l1)
#
# TypeError: cannot convert dictionary update sequence element #4 to a sequence

# %%
d1
# Out:
# {1: 2, 7: 8, 3: 4, 5: 6}

# %%
l1
# Out:
# [(1, 2), (3, 4), (5, 6), (7, 8), 7]

# %%
str(l1)
# Out:
# '[(1, 2), (3, 4), (5, 6), (7, 8), 7]'

# %%
d1
# Out:
# {1: 2, 7: 8, 3: 4, 5: 6}

# %%
set(d1)
# Out:
# {1, 3, 5, 7}

# %%
tuple(d1)
# Out:
# (1, 7, 3, 5)

# %%
d1
# Out:
# {1: 2, 7: 8, 3: 4, 5: 6}

# %%
list(d1)
# Out:
# [1, 7, 3, 5]

# %%
d1
# Out:
# {1: 2, 7: 8, 3: 4, 5: 6}
