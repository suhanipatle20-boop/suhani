# %% [markdown]
# ## variable

# %%
name = "amit"     # aslkdfjkjahsdf

# %%
1name = "amit"
# Out:
#   Cell In[2], line 1
#     1name = "amit"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "amit"

# %%
last name = "kumar"
# Out:
#   Cell In[4], line 1
#     last name = "kumar"
#          ^
# SyntaxError: invalid syntax

# %%
lastname = "kumar"

# %%
last$name = "kumar"
# Out:
#   Cell In[6], line 1
#     last$name = "kumar"
#         ^
# SyntaxError: invalid syntax

# %%
last*name = "kumar"
# Out:
#   Cell In[7], line 1
#     last*name = "kumar"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
last_name = "kumar"

# %%
 _ = 99

# %%
_
# Out:
# 99

# %%
a = 10
b= 20
c =             30

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
x, y,z = 10, 20, 30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
v, x, y,z = 10, 20, 30, 40

# %%
a
# Out:
# 10

# %%
a = 60

# %%
a
# Out:
# 60

# %%
x
# Out:
# 20

# %%
x= 60

# %%
a
# Out:
# 60

# %%
a = 10

# %%
10 = a
# Out:
#   Cell In[28], line 1
#     10 = a
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
b = 30

# %% [markdown]
# ## Data Types

# %%
int       = 0-9
float     =  5.78, 7.99
str       = " }}", ' 3252adga*^&'
bool      = True/ False
complex   =   56 + 7j

# %%
5X = y = 0

# %%
abc = 56+7j

# %%
abc
# Out:
# (56+7j)

# %% [markdown]
# ## data structure

# %%
list   = [4,5,7,7,"f",3,]

tuple  = (4,5,7,7,"f",3,)

set    =  {4,5,7,7,"f",3}

dict   =   {1:"jan", 2:"feb", 3:"march", }

# %%
var = {4,5,6}

# %%
var
# Out:
# {4, 5, 6}

# %%
type(var)
# Out:
# set

# %%
lis = []

# %%
type(lis)
# Out:
# list

# %%
A = "jan"

# %%
type(A)
# Out:
# str

# %%
A = 876

# %%
type(A)
# Out:
# int

# %%
d  =   {1:"jan", 2:"feb", 3:"march", 1:"April"}

# %%
d
# Out:
# {1: 'April', 2: 'feb', 3: 'march'}

# %%
a = 10
a = 20
a = 30

# %%
a
# Out:
# 30

# %%
iterable --- non -iterable

# %%
# non iterable

int
float
bool
complex

# %%
d = 7856544

# %%
T = True

# %%
# iterable

str
list
tuple
set
dict
